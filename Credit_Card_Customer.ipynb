# %% [markdown]
# # Random Forest Model

# %%
import pandas as pd 
import numpy as np
from sklearn.model_selection import train_test_split 
from sklearn.ensemble import RandomForestClassifier
import os

# %%
# Loading the data  
df = pd.read_csv(r'C:\Users\gjrre\Documents\Python Project\New folder\BankChurners.csv')

# %%
df.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  \
# 0              39  ...       12691.0                  777          11914.0
# ...

# %%
df = df.rename(str.lower, axis='columns')

# %%
df.columns
# Out:
# Index(['clientnum', 'attrition_flag', 'customer_age', 'gender',
#        'dependent_count', 'education_level', 'marital_status',
#        'income_category', 'card_category', 'months_on_book',
#        'total_relationship_count', 'months_inactive_12_mon',
#        'contacts_count_12_mon', 'credit_limit', 'total_revolving_bal',
#        'avg_open_to_buy', 'total_amt_chng_q4_q1', 'total_trans_amt',
#        'total_trans_ct', 'total_ct_chng_q4_q1', 'avg_utilization_ratio',
#        'naive_bayes_classifier_attrition_flag_card_category_contacts_count_12_mon_dependent_count_education_level_months_inactive_12_mon_1',
#        'naive_bayes_classifier_attrition_flag_card_category_contacts_count_12_mon_dependent_count_education_level_months_inactive_12_mon_2'],
#       dtype='object')

# %%
df1 = df.drop(df.columns[[0, 21, 22]], axis=1)

df1
# Out:
#           attrition_flag  customer_age gender  dependent_count  \
# 0      Existing Customer            45      M                3
# 1      Existing Customer            49      F                5
# 2      Existing Customer            51      M                3
# 3      Existing Customer            40      F                4
# 4      Existing Customer            40      M                3
# ...                  ...           ...    ...              ...
# 10122  Existing Customer            50      M                2
# 10123  Attrited Customer            41      M                2
# 10124  Attrited Customer            44      F                1
# 10125  Attrited Customer            30      M                2
# 10126  Attrited Customer            43      F                2
#
#       education_level marital_status income_category card_category  \
# 0         High School        Married     $60K - $80K          Blue
# 1            Graduate         Single  Less than $40K          Blue
# ...

# %%
df1['card_category'].unique()
# Out:
# array(['Blue', 'Gold', 'Silver', 'Platinum'], dtype=object)

# %%
# df_numeric = pd.get_dummies(df[['Gender', 'Education_Level', 'Marital_Status']])
# df_numeric

# %%
df1
# Out:
#           attrition_flag  customer_age gender  dependent_count  \
# 0      Existing Customer            45      M                3
# 1      Existing Customer            49      F                5
# 2      Existing Customer            51      M                3
# 3      Existing Customer            40      F                4
# 4      Existing Customer            40      M                3
# ...                  ...           ...    ...              ...
# 10122  Existing Customer            50      M                2
# 10123  Attrited Customer            41      M                2
# 10124  Attrited Customer            44      F                1
# 10125  Attrited Customer            30      M                2
# 10126  Attrited Customer            43      F                2
#
#       education_level marital_status income_category card_category  \
# 0         High School        Married     $60K - $80K          Blue
# 1            Graduate         Single  Less than $40K          Blue
# ...

# %%
df2 = df1

# %%
def non_numeric_data(df):
    '''
    converting non-numeric data columns to numeric entries
    '''
    columns = df.columns.values
    for column in columns:
        text_digit_vals = {}
        def convert_to_int(val):
            return text_digit_vals[val]
        
        if df[column].dtype != np.int64 and df[column].dtype != np.float64:
            column_contents = df[column].values.tolist()
            unique_elements = set(column_contents)
            x = 0
            for unique in unique_elements:
                if unique not in text_digit_vals:
                    text_digit_vals[unique] = x
                    x += 1
                    
            df[column] = list(map(convert_to_int, df[column]))
            
    return df

# %%
df_numeric = non_numeric_data(df2)
df_numeric.head()
# Out:
#    attrition_flag  customer_age  gender  dependent_count  education_level  \
# 0               0            45       1                3                5
# 1               0            49       0                5                6
# 2               0            51       1                3                6
# 3               0            40       0                4                5
# 4               0            40       1                3                3
#
#    marital_status  income_category  card_category  months_on_book  \
# 0               1                2              0              39
# 1               2                1              0              44
# 2               1                5              0              36
# 3               3                1              0              34
# 4               1                2              0              21
#
#    total_relationship_count  months_inactive_12_mon  contacts_count_12_mon  \
# ...

# %%
df_numeric['is_train'] = np.random.uniform(0, 1, len(df)) <= .60

# %%
df_numeric.head()
# Out:
#    attrition_flag  customer_age  gender  dependent_count  education_level  \
# 0               0            45       1                3                5
# 1               0            49       0                5                6
# 2               0            51       1                3                6
# 3               0            40       0                4                5
# 4               0            40       1                3                3
#
#    marital_status  income_category  card_category  months_on_book  \
# 0               1                2              0              39
# 1               2                1              0              44
# 2               1                5              0              36
# 3               3                1              0              34
# 4               1                2              0              21
#
#    total_relationship_count  ...  contacts_count_12_mon  credit_limit  \
# ...

# %%
# df2 = df1
# df2.rename(columns = {'card_category': 'card_category_name'}, inplace = True)
# extracted_col = df2['card_category_name']
# df_numeric = df_numeric.join(extracted_col)
# df_numeric

# %%
train, test = df_numeric[df_numeric['is_train'] == True], df_numeric[df_numeric['is_train'] == False]
print('Number of observations in training data set: ', len(train))
print('Number of observations in testing data set: ', len(test))
# Out:
# Number of observations in training data set:  6189
# Number of observations in testing data set:  3938

# %%
features = df_numeric.columns[0:]
features
# Out:
# Index(['attrition_flag', 'customer_age', 'gender', 'dependent_count',
#        'education_level', 'marital_status', 'income_category', 'card_category',
#        'months_on_book', 'total_relationship_count', 'months_inactive_12_mon',
#        'contacts_count_12_mon', 'credit_limit', 'total_revolving_bal',
#        'avg_open_to_buy', 'total_amt_chng_q4_q1', 'total_trans_amt',
#        'total_trans_ct', 'total_ct_chng_q4_q1', 'avg_utilization_ratio',
#        'is_train'],
#       dtype='object')

# %%
y = pd.factorize(train['card_category'])[0]

# %%
clf = RandomForestClassifier(n_jobs = 2, random_state = 0)
clf.fit(train[features], y)
# Out:
# RandomForestClassifier(n_jobs=2, random_state=0)

# %%
clf.predict(test[features])
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
clf.predict_proba(test[features])[0:10]
# Out:
# array([[1.  , 0.  , 0.  , 0.  ],
#        [1.  , 0.  , 0.  , 0.  ],
#        [1.  , 0.  , 0.  , 0.  ],
#        [0.99, 0.  , 0.01, 0.  ],
#        [1.  , 0.  , 0.  , 0.  ],
#        [0.98, 0.  , 0.02, 0.  ],
#        [1.  , 0.  , 0.  , 0.  ],
#        [1.  , 0.  , 0.  , 0.  ],
#        [0.97, 0.01, 0.02, 0.  ],
#        [1.  , 0.  , 0.  , 0.  ]])
